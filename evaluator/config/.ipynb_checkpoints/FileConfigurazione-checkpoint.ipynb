# %% [markdown]
# ## FILE DI CONFIGURAZIONE JSON

# %%
import json

# Esempio di configurazione generalizzata
config = {
  "datasets": {
    "train": "data/train.csv",             # oppure null se non disponibile
    "test": "data/test.csv",               # oppure null
    "predictions": "data/predictions.csv"  # oppure null
  },
  
  "model": {
    "path": "models/model.pkl",    // oppure null
    "type": "sklearn"              // sklearn / api / blackbox / altro
  },
  
  "sensitive_features": {
    "gender": "sesso",
    "age": "età",
    "ethnicity": "etnia"
  },
  
  "rights_to_evaluate": [
    "non_discrimination",
    "privacy"
  ],
  
  "metrics": {
    "non_discrimination": [
      "demographic_parity",
      "equal_opportunity"
    ],
    "privacy": [
      "membership_inference_risk"
    ]
  },
  
  "plugins": [
    "plugins.fairness.demographic_parity",
    "plugins.fairness.equal_opportunity",
    "plugins.privacy.membership_inference"
  ],
  
  "general": {
    "number_of_features": 25,
    "categorical_features": ["sesso", "etnia"],
    "numerical_features": ["età", "anni_esperienza"],
    "seed": 42,
    "sandbox_mode": true
  }
}
